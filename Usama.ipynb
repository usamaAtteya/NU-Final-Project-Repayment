# %%
# !pip install pandas
# !pip install -U scikit-learn
# !pip install matplotlib
# !pip install scipy
# !pip install seaborn
# !pip install statsmodels

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)}) # set font and plot size to be larger
pd.set_option('display.max_columns',2000) # show all columns in jupyter

# %%
# import sys
# sys.path.append("/Users/apple/.pyenv/versions/3.5.4/lib/python3.5/site-packages")
import seaborn as sns

# %%
def plotCorrelation(dataFrame,headersArray1,headersArray2):
    for header1 in headersArray1:
        for header2 in headersArray2:
            sns.relplot(x=header1, y=header2,data=dataFrame);

# %%
colsToLoad =["INSTNM","ADM_RATE","ADM_RATE_ALL","SATVR25","SATVR75","SATMT25","SATMT75","SATWR25","SATWR75","SATVRMID","SATMTMID","SATWRMID","ACTCM25","ACTCM75","ACTEN25","ACTEN75","ACTMT25","ACTMT75","ACTWR25","ACTWR75","ACTCMMID","ACTENMID","ACTMTMID","ACTWRMID","SAT_AVG","SAT_AVG_ALL","UGDS","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","UGDS_NHPI","UGDS_2MOR","UGDS_NRA","UGDS_UNKN","PPTUG_EF","COSTT4_A","COSTT4_P","TUITIONFEE_IN","TUITIONFEE_OUT","TUITIONFEE_PROG","TUITFTE","INEXPFTE","AVGFACSAL","PCTPELL","DEATH_YR3_RT","COMP_ORIG_YR3_RT","LOAN_DEATH_YR3_RT","LOAN_COMP_ORIG_YR3_RT","DEATH_YR4_RT","COMP_ORIG_YR4_RT","COMPL_RPY_1YR_RT","NONCOM_RPY_1YR_RT","AGE_ENTRY","COUNT_NWNE_P10","COUNT_WNE_P10","MN_EARN_WNE_P10","MD_EARN_WNE_P10","COMPL_RPY_3YR_RT","NONCOM_RPY_3YR_RT"]
scoreCardDF = pd.read_csv("CollegeScorecard_Raw_Data/MERGED2013_14_PP.csv", index_col="INSTNM",usecols=colsToLoad)
# Out:
# /Users/apple/.pyenv/versions/3.5.4/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1606) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
scoreCardDF.head()
# Out:
#                                      ADM_RATE  ADM_RATE_ALL  SATVR25  SATVR75  \
# INSTNM
# Alabama A & M University               0.8989        0.8989    370.0    450.0
# University of Alabama at Birmingham    0.8673        0.8673    520.0    640.0
# Amridge University                        NaN           NaN      NaN      NaN
# University of Alabama in Huntsville    0.8062        0.8062    510.0    640.0
# Alabama State University               0.5125        0.5125    380.0    480.0
#
#                                      SATMT25  SATMT75  SATWR25  SATWR75  \
# INSTNM
# Alabama A & M University               350.0    450.0      NaN      NaN
# University of Alabama at Birmingham    520.0    650.0      NaN      NaN
# Amridge University                       NaN      NaN      NaN      NaN
# University of Alabama in Huntsville    510.0    650.0      NaN      NaN
# Alabama State University               370.0    480.0      NaN      NaN
#
# ...

# %%
scoreCardDF.shape
# Out:
# (7804, 60)

# %%
scoreCardDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7804 entries, Alabama A & M University to Georgia Military College-Stone Mountain
# Data columns (total 60 columns):
# ADM_RATE                 2221 non-null float64
# ADM_RATE_ALL             2486 non-null float64
# SATVR25                  1303 non-null float64
# SATVR75                  1303 non-null float64
# SATMT25                  1317 non-null float64
# SATMT75                  1317 non-null float64
# SATWR25                  795 non-null float64
# SATWR75                  795 non-null float64
# SATVRMID                 1303 non-null float64
# SATMTMID                 1317 non-null float64
# SATWRMID                 795 non-null float64
# ACTCM25                  1344 non-null float64
# ACTCM75                  1344 non-null float64
# ACTEN25                  1167 non-null float64
# ACTEN75                  1167 non-null float64
# ACTMT25                  1168 non-null float64
# ACTMT75                  1168 non-null float64
# ...

# %%
scoreCardDF.describe()
# Out:
#           ADM_RATE  ADM_RATE_ALL      SATVR25     SATVR75      SATMT25  \
# count  2221.000000   2486.000000  1303.000000  1303.00000  1317.000000
# mean      0.683853      0.692173   467.396009   576.23254   476.647684
# std       0.208593      0.202677    68.307741    70.24794    73.252242
# min       0.000000      0.000000   265.000000   315.00000   280.000000
# 25%       0.554300      0.563350   420.000000   530.00000   430.000000
# 50%       0.701600      0.718500   460.000000   570.00000   460.000000
# 75%       0.835000      0.838784   500.000000   620.00000   510.000000
# max       1.000000      1.000000   720.000000   800.00000   770.000000
#
#            SATMT75     SATWR25     SATWR75     SATVRMID     SATMTMID  \
# count  1317.000000  795.000000  795.000000  1303.000000  1317.000000
# mean    585.021260  467.996226  574.345912   521.844206   530.869400
# std      72.724944   78.748947   78.460421    67.900031    71.719976
# ...

# %%
scoreCardDF.corr()
# Out:
#                  ADM_RATE  ADM_RATE_ALL   SATVR25   SATVR75   SATMT25  \
# ADM_RATE         1.000000      0.963624 -0.400103 -0.339047 -0.395480
# ADM_RATE_ALL     0.963624      1.000000 -0.390966 -0.331578 -0.389945
# SATVR25         -0.400103     -0.390966  1.000000  0.921798  0.937479
# SATVR75         -0.339047     -0.331578  0.921798  1.000000  0.879822
# SATMT25         -0.395480     -0.389945  0.937479  0.879822  1.000000
# SATMT75         -0.340965     -0.338530  0.890181  0.919377  0.931691
# SATWR25         -0.555350     -0.543022  0.964406  0.916663  0.933414
# SATWR75         -0.505395     -0.491294  0.927869  0.960373  0.905776
# SATVRMID        -0.376605     -0.368140  0.979688  0.980810  0.926493
# SATMTMID        -0.374764     -0.370698  0.929319  0.914724  0.982864
# SATWRMID        -0.538395     -0.524989  0.959551  0.951711  0.933346
# ACTCM25         -0.389851     -0.386808  0.927661  0.881432  0.931695
# ...

# %%
plotCorrelation(scoreCardDF,
                ["ADM_RATE","ADM_RATE_ALL","SATVR25","SATVR75","SATMT25","SATMT75","SATWR25","SATWR75","SATVRMID","SATMTMID","SATWRMID"],
                ["COMPL_RPY_3YR_RT"])

# %%
plotCorrelation(scoreCardDF,
                ["ADM_RATE","ADM_RATE_ALL","SATVR25","SATVR75","SATMT25","SATMT75","SATWR25","SATWR75","SATVRMID","SATMTMID","SATWRMID"],
                ["NONCOM_RPY_3YR_RT"])

# %%
plotCorrelation(scoreCardDF,
                ["ADM_RATE"],["SATVR25"])

# %%
plotCorrelation(scoreCardDF,
                ["ADM_RATE","ADM_RATE_ALL","SATVR25","SATVR75","SATMT25","SATMT75","SATWR25","SATWR75","SATVRMID","SATMTMID","SATWRMID","ACTCM25","ACTCM75","ACTEN25","ACTEN75","ACTMT25","ACTMT75","ACTWR25","ACTWR75","ACTCMMID","ACTENMID","ACTMTMID","ACTWRMID","SAT_AVG","SAT_AVG_ALL","UGDS","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","UGDS_NHPI","UGDS_2MOR","UGDS_NRA","UGDS_UNKN","PPTUG_EF","COSTT4_A","COSTT4_P","TUITIONFEE_IN","TUITIONFEE_OUT","TUITIONFEE_PROG","TUITFTE","INEXPFTE","AVGFACSAL","PCTPELL","DEATH_YR3_RT","COMP_ORIG_YR3_RT","LOAN_DEATH_YR3_RT","LOAN_COMP_ORIG_YR3_RT","DEATH_YR4_RT","COMP_ORIG_YR4_RT","COMPL_RPY_1YR_RT","NONCOM_RPY_1YR_RT","AGE_ENTRY","COUNT_NWNE_P10","COUNT_WNE_P10","MN_EARN_WNE_P10","MD_EARN_WNE_P10"],
                ["COMPL_RPY_3YR_RT"])

# %%
plotCorrelation(scoreCardDF,
                ["ADM_RATE","ADM_RATE_ALL","SATVR25","SATVR75","SATMT25","SATMT75","SATWR25","SATWR75","SATVRMID","SATMTMID","SATWRMID","ACTCM25","ACTCM75","ACTEN25","ACTEN75","ACTMT25","ACTMT75","ACTWR25","ACTWR75","ACTCMMID","ACTENMID","ACTMTMID","ACTWRMID","SAT_AVG","SAT_AVG_ALL","UGDS","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","UGDS_NHPI","UGDS_2MOR","UGDS_NRA","UGDS_UNKN","PPTUG_EF","COSTT4_A","COSTT4_P","TUITIONFEE_IN","TUITIONFEE_OUT","TUITIONFEE_PROG","TUITFTE","INEXPFTE","AVGFACSAL","PCTPELL","DEATH_YR3_RT","COMP_ORIG_YR3_RT","LOAN_DEATH_YR3_RT","LOAN_COMP_ORIG_YR3_RT","DEATH_YR4_RT","COMP_ORIG_YR4_RT","COMPL_RPY_1YR_RT","NONCOM_RPY_1YR_RT","AGE_ENTRY","COUNT_NWNE_P10","COUNT_WNE_P10","MN_EARN_WNE_P10","MD_EARN_WNE_P10"],
                ["NONCOM_RPY_3YR_RT"])

# %%
rr

# %%
#horizontal bat to find the most expensive institutes
costDf = scoreCardDF[['COSTT4_A']].sort_values(by='COSTT4_A',ascending=False).head(20)
ax = costDf.plot(kind='barh',title='Cost',legend=False)
ax.invert_yaxis()
